# %%
import pandas as pd

# %%
dataset=pd.read_csv("preplacement.csv")

# %%
dataset.drop(columns="sl_no",inplace =True)

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.columns
# Out:
# Index(['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',
#        'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status',
#        'salary'],
#       dtype='object')

# %%
dataset['gender'].dtype
# Out:
# dtype('O')

# %%
quan=[]
qual=[]
def quan_qual(dataset):
    for columnname in dataset:
        if dataset[columnname].dtype=="O":
             qual.append(columnname)
        else :
            quan.append(columnname)
    return quan,qual # always if u want to return more than 2 outputs give return output1,output2, etc.

# %%
quan,qual=quan_qual(dataset)

# %%
quan
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
quan # this is a list , but to run in a for loop u need an array that is the entire dataset in quan
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
np.array(quan)# to convert a list to array use numpy, np.array(list)
# Out:
# array(['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#       dtype='<U8')

# %%
dataset[quan]
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0    67.00  91.00     58.00     55.0  58.80  270000.0
# 1    79.33  78.33     77.48     86.5  66.28  200000.0
# 2    65.00  68.00     64.00     75.0  57.80  250000.0
# 3    56.00  52.00     52.00     66.0  59.43       0.0
# 4    85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...       ...      ...    ...       ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.0
# 211  58.00  60.00     72.00     74.0  53.62  275000.0
# 212  67.00  67.00     73.00     59.0  69.72  295000.0
# 213  74.00  66.00     58.00     70.0  60.23  204000.0
# 214  62.00  58.00     53.00     89.0  60.22       0.0
#
# [215 rows x 6 columns]

# %%
values=dataset[quan].values# to convert a dataframe to array use dataframe.values

# %%
values
# Out:
# array([[6.700e+01, 9.100e+01, 5.800e+01, 5.500e+01, 5.880e+01, 2.700e+05],
#        [7.933e+01, 7.833e+01, 7.748e+01, 8.650e+01, 6.628e+01, 2.000e+05],
#        [6.500e+01, 6.800e+01, 6.400e+01, 7.500e+01, 5.780e+01, 2.500e+05],
#        ...,
#        [6.700e+01, 6.700e+01, 7.300e+01, 5.900e+01, 6.972e+01, 2.950e+05],
#        [7.400e+01, 6.600e+01, 5.800e+01, 7.000e+01, 6.023e+01, 2.040e+05],
#        [6.200e+01, 5.800e+01, 5.300e+01, 8.900e+01, 6.022e+01, 0.000e+00]])

# %%
len(values)
# Out:
# 215

# %%
values.shape[0] #values.shape[0] gives total no of rows ,which is same as len(values)
# Out:
# 215

# %%
vif=[variance_inflation_factor(values,i)for i in range(values.shape[1])] #here values.shape[1] gives total column numbers 

# for i in range values.shape[1], means,when i=0 it refers to ssc_p,wen i=1 it means hsc_p.

# %%
vif
# Out:
# [76.49660319399253,
#  58.97206555099468,
#  113.29929752782598,
#  32.67965872900778,
#  114.02597180825704,
#  3.931111994917773]

# %%
vif_table=pd.DataFrame(vif,quan)

# %%
dataset.values
# Out:
# array([['M', 67.0, 'Others', ..., 58.8, 'Placed', 270000.0],
#        ['M', 79.33, 'Central', ..., 66.28, 'Placed', 200000.0],
#        ['M', 65.0, 'Central', ..., 57.8, 'Placed', 250000.0],
#        ...,
#        ['M', 67.0, 'Others', ..., 69.72, 'Placed', 295000.0],
#        ['F', 74.0, 'Others', ..., 60.23, 'Placed', 204000.0],
#        ['M', 62.0, 'Central', ..., 60.22, 'Not Placed', 0.0]],
#       dtype=object)

# %%
def vif(dataset):
    import numpy as np
    from statsmodels.stats.outliers_influence import variance_inflation_factor
    
    
    values=dataset.values
    vif=[variance_inflation_factor(values,i)for i in range(values.shape[1])]
    vif_table=pd.DataFrame({"vif_values":vif,"variables":dataset.columns})
    return vif_table

# %%
#here vif for salary is less than 5 so multicollinearity is less for salary with respect to others. for others are above 10.

# %%
vif(dataset[["ssc_p", "hsc_p"]])
# Out:
#    vif_values variables
# 0   40.164883     ssc_p
# 1   40.164883     hsc_p

# %%
dataset[quan]
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0    67.00  91.00     58.00     55.0  58.80  270000.0
# 1    79.33  78.33     77.48     86.5  66.28  200000.0
# 2    65.00  68.00     64.00     75.0  57.80  250000.0
# 3    56.00  52.00     52.00     66.0  59.43       0.0
# 4    85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...       ...      ...    ...       ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.0
# 211  58.00  60.00     72.00     74.0  53.62  275000.0
# 212  67.00  67.00     73.00     59.0  69.72  295000.0
# 213  74.00  66.00     58.00     70.0  60.23  204000.0
# 214  62.00  58.00     53.00     89.0  60.22       0.0
#
# [215 rows x 6 columns]

# %%
def vif(dataset):
    import numpy as np
    from statsmodels.stats.outliers_influence import variance_inflation_factor
    
    dataset=dataset[quan]
    values=dataset.values
    vif=[variance_inflation_factor(values,i)for i in range(values.shape[1])]
    vif_table=pd.DataFrame({"vif_values":vif,"variables":dataset.columns})
    return vif_table

# %%
vif(dataset)
# Out:
#    vif_values variables
# 0   76.496603     ssc_p
# 1   58.972066     hsc_p
# 2  113.299298  degree_p
# 3   32.679659   etest_p
# 4  114.025972     mba_p
# 5    3.931112    salary

# %%
dataset.columns
# Out:
# Index(['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',
#        'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status',
#        'salary'],
#       dtype='object')

# %%
dataset.drop(columns=["degree_p","ssc_p","mba_p"], )
# Out:
#     gender    ssc_b  hsc_p    hsc_b     hsc_s   degree_t workex  etest_p  \
# 0        M   Others  91.00   Others  Commerce   Sci&Tech     No     55.0
# 1        M  Central  78.33   Others   Science   Sci&Tech    Yes     86.5
# 2        M  Central  68.00  Central      Arts  Comm&Mgmt     No     75.0
# 3        M  Central  52.00  Central   Science   Sci&Tech     No     66.0
# 4        M  Central  73.60  Central  Commerce  Comm&Mgmt     No     96.8
# ..     ...      ...    ...      ...       ...        ...    ...      ...
# 210      M   Others  82.00   Others  Commerce  Comm&Mgmt     No     91.0
# 211      M   Others  60.00   Others   Science   Sci&Tech     No     74.0
# 212      M   Others  67.00   Others  Commerce  Comm&Mgmt    Yes     59.0
# 213      F   Others  66.00   Others  Commerce  Comm&Mgmt     No     70.0
# 214      M  Central  58.00   Others   Science  Comm&Mgmt     No     89.0
#
#     specialisation      status    salary
# 0           Mkt&HR      Placed  270000.0
# ...

# %% [markdown]
# # why do we need multicollinearity

# %%
# we need :
#1 to increase model stability
# 2 by reducing redundancy or feeding the model duplicate info and in return to prevent overfitting
# wen 2 inputs r too corelated then we wont understand how each input is affecting the output.
